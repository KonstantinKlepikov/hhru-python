# %%
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
df = pd.read_csv('../data/result_deep.csv')

# %%
df.sort_values(by=['employer'], inplace=True)

# %%
df
# Out:
#            id                                        name  \
# 88   70472405                            Python Developer
# 134  69695405  ETL-разработчик (уровень не ниже среднего)
# 131  70348684                  Ведущий разработчик Python
# 69   69988089                          Python разработчик
# 31   70727177     Преподаватель по Data Science на Python
# ..        ...                                         ...
# 77   70811041                                Дата инженер
# 158  69978113                      Data engineer (Middle)
# 17   70588588         Python Django разработчик, удаленно
# 23   70588586         Python Django разработчик, удаленно
# 11   70588587         Python Django разработчик, удаленно
#
#                                    area          experience  \
# 88   Петропавловка (Республика Бурятия)       От 3 до 6 лет
# 134                              Москва       От 3 до 6 лет
# 131                              Москва       От 3 до 6 лет
# 69                               Москва       От 3 до 6 лет
# 31                               Алматы       От 3 до 6 лет
# ..                                  ...                 ...
# 77                               Москва       От 3 до 6 лет
# 158                              Москва  От 1 года до 3 лет
# 17                               Самара       От 3 до 6 лет
# 23                          Новосибирск       От 3 до 6 лет
# 11                         Екатеринбург       От 3 до 6 лет
#
#               employment                                        description  \
# 88      Полная занятость  2people IT ― компания, предоставляющая техноло...
# 134     Полная занятость  Удалённая работа Обязанности:  Дизайн и разраб...
# 131     Полная занятость  ADV/web-engineering co. — разработка и развити...
# 69      Полная занятость  В ведущей международной табачной компании откр...
# 31   Частичная занятость  Мы активно развивающаяся онлайн-школа Academic...
# ..                   ...                                                ...
# 77      Полная занятость  В команду проекта «ERP Data flow» нужен Дата и...
# 158     Полная занятость    Что и как мы делаем? Мы создаем продвинутое ...
# 17      Полная занятость  Мы ищем опытного Python/django fullstack разра...
# 23      Полная занятость  Мы ищем опытного Python/django fullstack разра...
# 11      Полная занятость  Мы ищем опытного Python/django fullstack разра...
#
#                                             key_skills  \
# 88   ['Python', 'Django Framework', 'PostgreSQL', '...
# 134  ['Python', 'PostgreSQL', 'SQL', 'MS SQL Server...
# 131  ['Python', 'ООП', 'Git', 'Docker', 'Elasticsea...
# 69   ['Python', 'Django Framework', 'MS SQL', 'MLOps']
# 31   ['Python', 'Грамотная речь', 'Работа с людьми'...
# ..                                                 ...
# 77   ['Python', 'Hadoop', 'PostgreSQL', 'Linux', 'E...
# 158  ['SQL', 'SCALA', 'Linux', 'Работа в команде', ...
# 17             ['Python', 'Django Framework', 'React']
# 23             ['Python', 'Django Framework', 'React']
# 11             ['Python', 'Django Framework', 'React']
#
#                                        specializations  \
# 88   ['Программирование, Разработка', 'Системы упра...
# 134  ['Программирование, Разработка', 'Системы упра...
# 131  ['Программирование, Разработка', 'Системы упра...
# 69   ['Программирование, Разработка', 'Системы упра...
# 31   ['Программирование, Разработка', 'Системы упра...
# ..                                                 ...
# 77   ['Программирование, Разработка', 'Системы упра...
# 158  ['Программирование, Разработка', 'Системы упра...
# 17   ['Программирование, Разработка', 'Системы упра...
# 23   ['Программирование, Разработка', 'Системы упра...
# 11   ['Программирование, Разработка', 'Системы упра...
#
#                professional_roles             employer  \
# 88   ['Программист, разработчик']           2people IT
# 134  ['Программист, разработчик']            7RedLines
# 131  ['Программист, разработчик']  ADV/web-engineering
# 69   ['Программист, разработчик']                ANCOR
# 31   ['Программист, разработчик']            Academica
# ..                            ...                  ...
# 77   ['Программист, разработчик']               билайн
# 158  ['Программист, разработчик']               билайн
# 17   ['Программист, разработчик']                эдмин
# 23   ['Программист, разработчик']                эдмин
# 11   ['Программист, разработчик']                эдмин
#
#                  published_at                created_at  \
# 88   2022-09-28T14:53:07+0300  2022-09-28T14:53:07+0300
# 134  2022-10-06T09:11:33+0300  2022-10-06T09:11:33+0300
# 131  2022-09-26T12:57:13+0300  2022-09-26T12:57:13+0300
# 69   2022-09-26T07:55:31+0300  2022-09-26T07:55:31+0300
# 31   2022-10-04T08:47:10+0300  2022-10-04T08:47:10+0300
# ..                        ...                       ...
# 77   2022-10-05T14:27:58+0300  2022-10-05T14:27:58+0300
# 158  2022-10-07T15:23:55+0300  2022-10-07T15:23:55+0300
# 17   2022-10-06T16:28:02+0300  2022-10-06T16:28:02+0300
# 23   2022-10-06T16:28:02+0300  2022-10-06T16:28:02+0300
# 11   2022-10-06T16:28:02+0300  2022-10-06T16:28:02+0300
#
#                                    apply_alternate_url  \
# 88   https://hh.ru/applicant/vacancy_response?vacan...
# 134  https://hh.ru/applicant/vacancy_response?vacan...
# 131  https://hh.ru/applicant/vacancy_response?vacan...
# 69   https://hh.ru/applicant/vacancy_response?vacan...
# 31   https://hh.ru/applicant/vacancy_response?vacan...
# ..                                                 ...
# 77   https://hh.ru/applicant/vacancy_response?vacan...
# 158  https://hh.ru/applicant/vacancy_response?vacan...
# 17   https://hh.ru/applicant/vacancy_response?vacan...
# 23   https://hh.ru/applicant/vacancy_response?vacan...
# 11   https://hh.ru/applicant/vacancy_response?vacan...
#
#                       alternate_url  \
# 88   https://hh.ru/vacancy/70472405
# 134  https://hh.ru/vacancy/69695405
# 131  https://hh.ru/vacancy/70348684
# 69   https://hh.ru/vacancy/69988089
# 31   https://hh.ru/vacancy/70727177
# ..                              ...
# 77   https://hh.ru/vacancy/70811041
# 158  https://hh.ru/vacancy/69978113
# 17   https://hh.ru/vacancy/70588588
# 23   https://hh.ru/vacancy/70588586
# 11   https://hh.ru/vacancy/70588587
#
#                                              languages       from        to  \
# 88                                                 NaN        NaN       NaN
# 134                                                NaN   140000.0  180000.0
# 131                                                NaN        NaN       NaN
# 69                                                 NaN        NaN       NaN
# 31                                                 NaN  1000000.0       NaN
# ..                                                 ...        ...       ...
# 77                                                 NaN        NaN       NaN
# 158  [{'id': 'eng', 'name': 'Английский', 'level': ...        NaN       NaN
# 17                                                 NaN   150000.0  200000.0
# 23                                                 NaN   150000.0  200000.0
# 11                                                 NaN   150000.0  200000.0
#
#     currency  gross
# 88       NaN    NaN
# 134      RUR  False
# 131      NaN    NaN
# 69       NaN    NaN
# 31       KZT  False
# ..       ...    ...
# 77       NaN    NaN
# 158      NaN    NaN
# 17       RUR   True
# 23       RUR   True
# 11       RUR   True
#
# [328 rows x 19 columns]

# %%
df.to_csv('../data/result_deep_sorted.csv', index=False)
